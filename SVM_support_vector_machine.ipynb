# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from math import sqrt
from mpl_toolkits.mplot3d import Axes3D

# Some code (such as the code to do PCA) will generate useless warnings
# We will suppress these warning using the code below
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## 2 Linear SVM

# %%
from sklearn.datasets.samples_generator import make_blobs
Xy1 = np.genfromtxt('svmlin.csv',delimiter=',')
X1 = Xy1[:,:2]
y1 = Xy1[:,2]
# Each datapoint in X is tuple of values (x0, x1). Lets plot them 
# on x and y axes respectively.
plt.scatter(X1[:, 0], X1[:, 1], c=y1, s=50, cmap='autumn');
plt.xlabel(r"$x_0$")
plt.ylabel(r"$x_1$")
plt.grid()

# %% [markdown]
# ### Marginal distance from a hyperplane

# %% [markdown]
# Find two lines that classify the red X as two different classes without changin the label of any of the points.

# %%
xfit = np.linspace(0, 3)
plt.scatter(X1[:, 0], X1[:, 1], c=y1, s=50, cmap='autumn')
plt.plot([0.6], [2.1], 'x', color='red', markeredgewidth=2, markersize=10)


# TODO
# plot two lines that classify X differently

for m, b in [(0.3, 2.3),  (0.8, 1.3)]:
    plt.plot(xfit, m * xfit + b, '-k')

# %% [markdown]
# Find margin for both of you lines

# %%
def calculate_margin(m,b,X):
    # TODO
    # find the minimum margin distance to the given line
    margins = []
    for x in X:
        marg = abs(x[1]+m*x[0]+b)/sqrt(m**2+1)
        margins.append(marg)# calculate distance for each X
    return np.min(margins)

# %%
# TODO
# check the values of minimum margin for your lines
print('margin of the first line: %.3f'%calculate_margin(0.3, 2.3,X1))
print('margin of the second line: %.3f'%calculate_margin(0.8, 1.3,X1))
# Out:
# margin of the first line: 2.637
# margin of the second line: 2.117

# %% [markdown]
# what values of m and b do you use for your line?

# %% [markdown]
# * Line 1: 0.3, 2.3  ||  Line 2: 0.8, 1.3

# %% [markdown]
# Plot the line. Which line gets a better margin? Why?

# %% [markdown]
# * Line 1 gets a better margin because it can classify the X as yellow while keeping minimum distance to class points high.

# %% [markdown]
# Fit a support vector model to the dataset:

# %%
from sklearn.svm import SVC # "Support vector classifier"

# %%
model = SVC(kernel='linear', C=1E10)
model.fit(X1, y1)
# Out:
# SVC(C=10000000000.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# Complete the function below for ploting the SVM boundry:

# %%
def plot_svc_decision_function(X, y, model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    # plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=.5,
               linestyles=['--', '-', '--'])
    
    # plot a black dot over the support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s = 20, facecolor= 'black');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.set_facecolor('lightgray')

# %%
plt.scatter(X1[:, 0], X1[:, 1], c=y1, s=50, cmap='autumn')
plot_svc_decision_function(X1, y1 ,model, plot_support=True);

# %% [markdown]
# Plot the decision boundary and indicate the support vectors. How many
# support vectors are in the plot? Explain why they are chosen as the
# support vectors.

# %% [markdown]
# * There are 3 support vectors in the plot.
#   The support vectors chosen are those closest to the boundary on each side. The model finds a boundary where the normal distance to any data point is maximized, and in this case the line is parallel to two red data points, such that we get 2 red points (equally close) and one yellow point as support vectors.

# %% [markdown]
# ## 3 Kernel SVM

# %%
Xy2 = np.genfromtxt('svmnonlin.csv',delimiter=',')
X2 = Xy2[:,:2]
y2 = Xy2[:,2]
sc = plt.gca()
sc.set_facecolor('lightgray')
sc.scatter(X2[:, 0], X2[:, 1],c=y2, s=50, cmap='autumn')

# %%
clf = SVC(kernel='linear', C=1) # fit a linear SVM with C=1 
clf.fit(X2, y2)

plt.scatter(X2[:, 0], X2[:, 1], c=y2, s=50, cmap='autumn')
plot_svc_decision_function(X2, y2 ,clf, plot_support=True);

# %% [markdown]
# What is the result of fitting a linear SVM to the data? Why?

# %% [markdown]
# * The result is a useless boundary, since the data set is not linearly separable in these dimensions.

# %%
from sklearn.metrics.pairwise import polynomial_kernel, rbf_kernel

# %%
# Computes the weighted sum of kernel values
def compute_f(training_points , test_point, kernel, weights, gamma=1, intercept=0):
    f = 0
    for i in range(len(training_points)):
        trainSample = [training_points[i]] # put the training sample into two diemnsions
        f += weights[i]*kernel(trainSample) # Complete the dual formula  (alpha*y = weights for every training sample)
    return f + intercept

# %%
def surface_kernel(X,y,weights,clf,kernel):
    p = np.linspace(0, 6, 10)
    xx1, xx2 = np.meshgrid(p, p)

    z = float('NaN')*np.ones(xx1.shape)

    intercept = clf.intercept_
    for i in range(z.shape[0]):
        for j in range(z.shape[1]):
            tst = [[xx1[i, j], xx2[i, j]]]
            z[i, j] = compute_f(X, tst, kernel, weights, gamma=1, intercept=intercept)
    zz = np.empty(y.shape)

    for i in range(X.shape[0]):
        zz[i] = compute_f(X, [X[i,:]], kernel, weights, gamma=1, intercept=intercept)

    return xx1,xx2,z,zz

# %%
def twodprojection(X,model):

    x_min = np.min(X[:, 0])
    y_min = np.min(X[:, 1])
    x_max = np.max(X[:, 0])
    y_max = np.max(X[:, 1])
    h = 0.01

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                             np.arange(y_min, y_max, h))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

    Z = Z.reshape(xx.shape)
    return xx,yy,Z

# %% [markdown]
# Fit a svm with RBF kernel to the dataset: (set the kernel value to 'rbf' and gamma to 1)

# %%
clf = SVC(gamma=1) #Fit a SVM model with RBF kernel and gamma = 1 
clf.fit(X2,y2)
weights = np.zeros((X2.shape[0], 1))
weights[clf.support_] = clf.dual_coef_.T

# %% [markdown]
# Plot the 3D projection of the surface of dual function of SVM:

# %%
xx1, xx2, z, zz = surface_kernel(X2,y2,weights,clf,rbf_kernel)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx1, xx2, z, alpha=0.5)
ax.view_init(elev=45, azim=-30)
ax.scatter(X2[:, 0], X2[:, 1], zz, s=30,c=y2,cmap='autumn')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# Plot the decision boundaries for RBF kernel:

# %%
# Plot decision boundary
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFCCCC', '#80dfff'])
xx,yy,Z = twodprojection(X2,clf)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
plt.scatter(X2[:, 0], X2[:, 1],c=y2, s=50, cmap='autumn')
plt.show()

# %% [markdown]
# Fit a svm with RBF kernel to the dataset: (set the kernel value to 'poly' and gamma to 1 and degree to 2)

# %%
clf_poly = SVC(kernel='poly', degree=2, gamma=1) # Fit a SVM with second degree polynomial kernel and gamma = 1
clf_poly.fit(X2,y2)
weights = np.zeros((X2.shape[0], 1))
weights[clf_poly.support_] = clf_poly.dual_coef_.T

# %%
xx1, xx2, z, zz = surface_kernel(X2,y2,weights,clf_poly,polynomial_kernel)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx1, xx2, z, alpha=0.5)
ax.scatter(X2[:, 0], X2[:, 1], zz, s=30,c=y2,cmap='autumn')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# Plot the decision boundaries for Polynomial kernel:

# %%
# Plot decision boundary
xx,yy,Z = twodprojection(X2,clf_poly)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
plt.scatter(X2[:, 0], X2[:, 1],c=y2, s=50, cmap='autumn')

plt.show()

# %% [markdown]
# How is this surface different than the RBF surface? which one classifies
# the data better?

# %% [markdown]
# * The RBF model classifies the data with more accuracy

# %% [markdown]
# ## 4 Tuning the SVM: Softening Margins

# %% [markdown]
# Generate the dataset by running the code below:

# %%
#from sklearn.datasets.samples_generator import make_blobs

Xy3 = np.genfromtxt('svmmargin.csv',delimiter=',')
X3 = Xy3[:,:2]
y3 = Xy3[:,2]
sc2 = plt.gca()
sc2.set_facecolor('lightgray')
plt.scatter(X3[:, 0], X3[:, 1], c=y3, s=30, cmap='autumn');
plt.xlabel(r"$x_0$")
plt.ylabel(r"$x_1$")
# Out:
# Text(0, 0.5, '$x_1$')

# %% [markdown]
# Fit two different SVMs with C=10 and C=0.1:

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 8))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

for axi, C in zip(ax, [10.0, 0.1]):
    model = SVC(kernel='linear', C=C) # fit a linear SVM with C=C
    model.fit(X3,y3)
    axi.scatter(X3[:, 0], X3[:, 1], c=y3, s=50, cmap='autumn')
    plot_svc_decision_function(X3,y3,model, axi)
    axi.set_title('C = {0:.1f}'.format(C), size=14)

# %% [markdown]
# What is different about the plot with C = 10 and C = 0:1? How does the
# value of C effect the number of support vectors?

# %% [markdown]
# * The model with a higher value of C creates a more narrow gap with fewer points allowed to populate it. A lower value of C results in more support vectors.

# %% [markdown]
# Load the iris dataset and split it into training and test sets and perform cross validation on the training set:
# ##### Hints:
# Use `train_test_split` and `cross_val_score` from `sklearn.model_selection` to split the dataset and perform cross validation for best value of $C$, respectively.

# %%
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn import datasets
import pandas as pd

# %%
# Split the dataset into training and test set. (75% to 25%)
iris = datasets.load_iris()
df = pd.DataFrame(iris['data']); df[4] = iris['target']
train, test = train_test_split(df, test_size=0.25)
train = train.values; test = test.values
X_train, X_test = train[:, :4], test[:, :4]
y_train, y_test = train[:, 4], test[:, 4]

# %%
score_list = []
C_list = np.arange(0.1,20,0.05)
# TODO
# perform cross validation on the training set 
for C in C_list: 
    clf = SVC(kernel='linear', C=C)
    clf.fit(X_train, y_train)
    score = cross_val_score(clf, X_train, y_train)
    score_list.append(score.mean())
best_C = C_list[np.argmax(score_list)]
print('The best value for C is :%.3f'%best_C)
# Out:
# The best value for C is :0.150

# %% [markdown]
# Measure the accuracy score on the test set

# %%
from sklearn.metrics import accuracy_score
clf = SVC(kernel='linear', C=best_C)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %% [markdown]
# What value of C do you get? What is the accuracy?

# %% [markdown]
# * See printed result above. When running the import and split of the data set again, I get varying results for best_C, and then also varying results of accuracy score. The range of best_C seems to be 0.15-2.3 and accuracy score 0.92-1. I assume this is because the data set is so small that how the train / test sets are split has a large impact on the model.

# %% [markdown]
# ## 5 Kernel Trick

# %% [markdown]
# Complete the implementation of phi:

# %%
def phi(x):
    # TODO
    # Complete the implementation
    transformed_x = np.empty(0)
    orig = len(x)
    for i in range(orig):
        transformed_x = np.concatenate((transformed_x,x[i]**2))# Power of two terms
        
    for i in range(orig):
        for j in range(orig):
            if (i!=j):
                transformed_x = np.concatenate((transformed_x,sqrt(2)*x[i]*x[j])) # Multipilication Terms
    for i in range(orig):
        transformed_x = np.concatenate((transformed_x, sqrt(2)*x[i])) #single Terms
    
    transformed_x = np.concatenate((transformed_x,[1]))
    return transformed_x

# %% [markdown]
# Measure the run time in normal way:

# %%
import timeit
np.random.seed(3)
run_time = []
kernel_values = []
for d in range(1,500,100):
    start = timeit.default_timer()

    x = np.random.uniform(0,100,[d,1])
    z = np.random.uniform(0,100,[d,1])
    x_k = phi(x)
    z_k = phi(z)
    Kxz = np.dot(x_k.T, z_k)
    kernel_values.append(Kxz) # the value of K(x,z) using phi
    
    stop = timeit.default_timer()
    run_time.append(stop - start)

# %% [markdown]
# Measure the run time for Kernel Trick:

# %%
np.random.seed(3)
run_time_trick = []
kernel_values_trick = []
for d in range(1,500,100):
    start = timeit.default_timer()

    x = np.random.uniform(0,100,[d,1])
    z = np.random.uniform(0,100,[d,1])
    Kxz = (1+np.dot(x.T, z))**2
    kernel_values_trick.append(Kxz) # the value of K(x,z) using kernel trick 
    
    stop = timeit.default_timer()
    run_time_trick.append(stop - start)

# %% [markdown]
# Plot the run times:

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,500,100),run_time,'R',label='run time for high dimensional computation')
plt.plot(range(1,500,100),run_time_trick,'B',label='run time for kernel trick')
plt.grid()
plt.xlabel('Dimensions')
plt.ylabel('run time')
plt.legend()

# %% [markdown]
# Compare the values of the kernel:

# %%
kernel_values
# Out:
# [15221416.30344801,
#  111957694162.78455,
#  434040844447.51117,
#  1287580653567.4119,
#  2116273589010.8057]

# %%
kernel_values_trick
# Out:
# [array([[15221416.30344801]]),
#  array([[5.64738645e+10]]),
#  array([[2.17929574e+11]]),
#  array([[6.45594747e+11]]),
#  array([[1.06049246e+12]])]

# %% [markdown]
# ## Naïve Bayes Classification

# %% [markdown]
# ![](naive_bayes1.png)

# %% [markdown]
# ![](naive_bayes2.png)
